# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tags5 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/5.txt', header=None)
tags20 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/20.txt', header=None)
tags40 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/40.txt', header=None)
tags80 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/80.txt', header=None)
tags160 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/160.txt', header=None)

# %%
tags5
# Out:
#     0       1       2
# 0   1  0.0137  0.2906
# 1   3  0.0357  0.2524
# 2   5  0.0558  0.2365
# 3  10  0.0973  0.2064
# 4  40  0.2600  0.1429

# %%
tags5[0]
# Out:
# 0     1
# 1     3
# 2     5
# 3    10
# 4    40
# Name: 0, dtype: int64

# %%
plt.plot(tags5[0], tags5[1], 'r--', label='k = 5')
plt.plot(tags20[0], tags20[1], 'bo', label='k = 20')
plt.plot(tags40[0], tags40[1], "w+" ,label='k = 40')
plt.plot(tags80[0], tags80[1], 'g^' ,label='k = 80')
plt.plot(tags160[0], tags160[1] ,label='k = 160')
plt.xlabel('n - recommendation')
plt.ylabel('recall')
# plt.show()
plt.legend(loc='upper center')
plt.savefig('recall.png', transparent=True)

# %%
plt.plot(tags5[0], tags5[2], 'r--', label='k = 5')
plt.plot(tags20[0], tags20[2], 'bo', label='k = 20')
plt.plot(tags40[0], tags40[2], "w+" ,label='k = 40')
plt.plot(tags80[0], tags80[2], 'g^' ,label='k = 80')
plt.plot(tags160[0], tags160[2] ,label='k = 160')
plt.xlabel('n - recommendation')
plt.ylabel('precision')
# plt.show()
plt.legend(loc='upper center')
plt.savefig('precision.png', transparent=True)

# %%
plt.plot(tags5[2], tags5[1], 'r--', label='k = 5')
plt.plot(tags20[2], tags20[1], 'bo', label='k = 20')
plt.plot(tags40[2], tags40[1], "w+" ,label='k = 40')
plt.plot(tags80[2], tags80[1], 'g^' ,label='k = 80')
plt.plot(tags160[2], tags160[1] ,label='k = 160')
plt.ylabel('recall')
plt.xlabel('precision')
# plt.show()
plt.legend(loc='upper center')
plt.savefig('precision-recall.png', transparent=True)

# %%
tagsals = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/40.txt', header=None)

# %%
tagsals
# Out:
#      0         1
# 0   20  0.043938
# 1   40  0.039641
# 2   60  0.037634
# 3   80  0.033778
# 4  100  0.031868
# 5  120  0.031829
# 6  140  0.030210
# 7  160  0.028638
# 8  180  0.027801
# 9  200  0.027150

# %%
plt.plot(tagsals[0], tagsals[1], 'r--o', label='ALS')
plt.xlabel('n - recommendation')
plt.ylabel('precision')
# plt.show()
plt.legend(loc='upper center')
plt.savefig('precisionAls.png', transparent=True)

# %%
tagsnmf = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/40.txt', header=None)

# %%
tagsnmf
# Out:
#     0         1         2
# 0   1  0.007423  0.074231
# 1   3  0.018664  0.062213
# 2   5  0.030223  0.060445
# 3  10  0.061188  0.061188

# %%
plt.plot(tagsnmf[0], tagsnmf[1], 'r--', label='recall')

plt.xlabel('n - recommendation')
plt.ylabel('metrics')
# plt.show()
plt.legend(loc='upper center')
plt.savefig('nmf.png', transparent=True)

# %%
tagsmf = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/40.txt', header=None)

# %%
tagsmf
# Out:
#       0       1       2
# 0    50  0.0031  0.5672
# 1   100  0.0058  0.5289
# 2  1000  0.0426  0.4776
# 3  5000  0.1830  0.4420
# 4  8000  0.2796  0.4113
# 5  9000  0.3249  0.3450

# %%
plt.plot(tagsmf[0], tagsmf[1], 'r--', label='recall')
plt.plot(tagsmf[0], tagsmf[2], 'r--', label='presicion')
plt.xlabel('n - recommendation')
plt.ylabel('metrics')
# plt.show()
plt.legend(loc='upper center')
plt.savefig('mf.png')

# %%
tagsmf = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/40.txt', header=None)

# %%
tags5 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/5.txt', header=None)
tags20 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/20.txt', header=None)
tags40 = pd.read_table('C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/40.txt', header=None)

# %%
plt.plot(tags5[0], tags5[1], 'r--', label='k = 5')
plt.plot(tags20[0], tags20[1], 'bo', label='k = 20')
plt.plot(tags40[0], tags40[1], "g" ,label='k = 40')
plt.ylabel('recall')
plt.xlabel('k-recommendation')
# plt.show()
plt.legend(loc='upper center')
plt.savefig('myalgo-recall.png', transparent=True)
