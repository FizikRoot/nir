# %%
import sys, util
import metrics
import numpy as np


def metric(trainSet, testSet, recoSet,k):
    pres = 0
    ndcg = 0
    count  = 0
    for userID in trainSet:
        testItems = testSet.get(userID, { })
        recoItems = recoSet.get(userID, { })
        
        r = []
        for itemID, rat in recoItems.iteritems():
            if itemID in testItems:
                rating = testItems.get(itemID)
                r.append(1 if rat-0.49 < rating else 0)
        if len(r) > 1:
            count += 1
            pres += metrics.precision_at_k(r,min(k, len(r)))
        ndcg += metrics.ndcg_at_k(r,k)
    if count == 0:
        count = 1
    return 1.0*pres/count,1.0*ndcg/count
 
def calcItemSimilarity(trainSet):
    import math
 
    counter   = dict()
    simMatrix = dict()    
 
    for userID, items in trainSet.items():
        for i in items:
            counter.setdefault(i, 0)
            counter[i] += 1
 
            simItems = simMatrix.setdefault(i, dict())
 
            for j in items:
                if j != i:
                    simItems.setdefault(j, 0)
                    simItems[j] += 1
 
    for i, simItems in simMatrix.items():
        for j, simIJ in simItems.items():
            simMatrix[i][j] /= math.sqrt(counter[i] * counter[j])
 
    return simMatrix
 
def calcIUFItemSimilarity(trainSet):
    import math
 
    counter   = dict()
    simMatrix = dict()    
 
    for userID, items in trainSet.items():
        for i in items:
            counter.setdefault(i, 0)
            counter[i] += 1
 
            simItems = simMatrix.setdefault(i, dict())
 
            for j in items:
                if j != i:
                    simItems.setdefault(j, 0)
                    simItems[j] += 1 / math.log(1 + len(items), math.e)
 
    for i, simItems in simMatrix.items():
        for j, simIJ in simItems.items():
            simMatrix[i][j] /= math.sqrt(counter[i] * counter[j])
 
    return simMatrix
 
def calcNormalizedItemSimilarity(trainSet):
    import math
 
    counter   = dict()
    simMatrix = dict()    
 
    for userID, items in trainSet.items():
        for i in items:
            counter.setdefault(i, 0)
            counter[i] += 1
 
            simItems = simMatrix.setdefault(i, dict())
 
            for j in items:
                if j != i:
                    simItems.setdefault(j, 0)
                    simItems[j] += 1
 
    for i, simItems in simMatrix.items():
        maxVal = 0
 
        for j, simIJ in simItems.items():
            simItems[j] = simIJ / math.sqrt(counter[i] * counter[j])
            if simItems[j] > maxVal:
                maxVal = simItems[j]
 
        for j, simIJ in simItems.items():
            simItems[j] = simIJ / maxVal
 
    return simMatrix
 
def calcRecommendation(trainSet, userID, simMatrix, K, N):
    import operator
 
    rank = dict()
 
    items = trainSet.get(userID)
    if items == None:
        return rank
 
    for i, rating in items.items():
        simItems = simMatrix.get(i)
        if simItems == None:
            continue
 
        for j, simIJ in sorted(simItems.items(), key = operator.itemgetter(1), reverse = True)[:K]:
            if not j in items:
                rank.setdefault(j, 0)
                rank[j] += rating * simIJ
 
    if len(rank) <= N:
        return rank
 
    ret = dict()
    for itemID, rating in sorted(rank.items(), key = operator.itemgetter(1), reverse = True)[:N]:
        ret[itemID] = rating
    return ret
 
if __name__ == "__main__":
    trainSet = util.loadDataSet("C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/u1.base", "\t")
    testSet  = util.loadDataSet("C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/u1.test", "\t")
    
    simMatrix = calcItemSimilarity(trainSet)
 
    K = 5   # k-nearest neighbors
    N = 40  # n-top recommendations
    for N in [1, 3, 5, 10, 40]:
        for K in [ 5, 20, 40, 80, 160 ]:
            recSet = { }
            for userID in trainSet:
                recSet[userID] = calcRecommendation(trainSet, userID, simMatrix, K, N)
            pres, ndcg=metric(trainSet, testSet, recSet,K)

            print "n = %s, k = %s, recall = %.4lf, precision = %.4lf, coverage = %.4lf, popularity = %.4lf, p_at_k = %.4lf, ndcg = %.4lf" %(
                N, K, 
                util.recall(trainSet, testSet, recSet),
                util.precision(trainSet, testSet, recSet),
                util.coverage(trainSet, testSet, recSet),
                util.popularity(trainSet, testSet, recSet),
                pres, ndcg
            )
        print
    print
    # inverse user frequence
    print 'inverse user frequence'
    simMatrix = calcIUFItemSimilarity(trainSet)
 
    K = 5   # k-nearest neighbors
    N = 40  # n-top recommendations
 
    for N in [1, 3, 5, 10, 40]:
        for K in [ 5, 20, 40, 80, 160 ]:
            recSet = { }
            for userID in trainSet:
                recSet[userID] = calcRecommendation(trainSet, userID, simMatrix, K, N)
            pres, ndcg=metric(trainSet, testSet, recSet,K)

            print "n = %s, k = %s, recall = %.4lf, precision = %.4lf, coverage = %.4lf, popularity = %.4lf, p_at_k = %.4lf, ndcg = %.4lf" %(
                N, K, 
                util.recall(trainSet, testSet, recSet),
                util.precision(trainSet, testSet, recSet),
                util.coverage(trainSet, testSet, recSet),
                util.popularity(trainSet, testSet, recSet),
                pres, ndcg
            )
        print
    print
    
    print 'Normalized Similarity'
    simMatrix = calcNormalizedItemSimilarity(trainSet)
 
    K = 5   # k-nearest neighbors
    N = 40  # n-top recommendations
 
    for N in [1, 3, 5, 10, 40]:
        for K in [ 5, 20, 40, 80, 160 ]:
            recSet = { }
            for userID in trainSet:
                recSet[userID] = calcRecommendation(trainSet, userID, simMatrix, K, N)
            pres, ndcg=metric(trainSet, testSet, recSet,K)

            print "n = %s, k = %s, recall = %.4lf, precision = %.4lf, coverage = %.4lf, popularity = %.4lf, p_at_k = %.4lf, ndcg = %.4lf" %(
                N, K, 
                util.recall(trainSet, testSet, recSet),
                util.precision(trainSet, testSet, recSet),
                util.coverage(trainSet, testSet, recSet),
                util.popularity(trainSet, testSet, recSet),
                pres, ndcg
            )
        print
# Out:
# n = 1, k = 5, recall = 0.0137, precision = 0.2906, coverage = 0.0418, popularity = 5.6771, p_at_k = 0.0000, ndcg = 1.0000
# n = 1, k = 20, recall = 0.0138, precision = 0.2916, coverage = 0.0436, popularity = 5.6805, p_at_k = 0.0000, ndcg = 1.0000
# n = 1, k = 40, recall = 0.0129, precision = 0.2725, coverage = 0.0442, popularity = 5.6986, p_at_k = 0.0000, ndcg = 1.0000
# n = 1, k = 80, recall = 0.0132, precision = 0.2800, coverage = 0.0497, popularity = 5.7069, p_at_k = 0.0000, ndcg = 0.0000
# n = 1, k = 160, recall = 0.0140, precision = 0.2959, coverage = 0.0521, popularity = 5.7178, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 3, k = 5, recall = 0.0357, precision = 0.2524, coverage = 0.0842, popularity = 5.5956, p_at_k = 0.0171, ndcg = 0.0342
# n = 3, k = 20, recall = 0.0355, precision = 0.2506, coverage = 0.0758, popularity = 5.6261, p_at_k = 0.0000, ndcg = 0.0043
# n = 3, k = 40, recall = 0.0340, precision = 0.2400, coverage = 0.0788, popularity = 5.6252, p_at_k = 0.0000, ndcg = 0.0046
# n = 3, k = 80, recall = 0.0352, precision = 0.2492, coverage = 0.0776, popularity = 5.6310, p_at_k = 0.0000, ndcg = 0.0000
# n = 3, k = 160, recall = 0.0362, precision = 0.2563, coverage = 0.0818, popularity = 5.6404, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 5, k = 5, recall = 0.0558, precision = 0.2365, coverage = 0.1285, popularity = 5.5340, p_at_k = 0.0373, ndcg = 0.0861
# n = 5, k = 20, recall = 0.0554, precision = 0.2350, coverage = 0.1012, popularity = 5.5869, p_at_k = 0.0049, ndcg = 0.0065
# n = 5, k = 40, recall = 0.0538, precision = 0.2282, coverage = 0.0976, popularity = 5.5803, p_at_k = 0.0000, ndcg = 0.0035
# n = 5, k = 80, recall = 0.0543, precision = 0.2303, coverage = 0.0982, popularity = 5.5852, p_at_k = 0.0000, ndcg = 0.0033
# n = 5, k = 160, recall = 0.0566, precision = 0.2401, coverage = 0.1018, popularity = 5.5933, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 10, k = 5, recall = 0.0973, precision = 0.2064, coverage = 0.2370, popularity = 5.3876, p_at_k = 0.0987, ndcg = 0.2095
# n = 10, k = 20, recall = 0.0990, precision = 0.2101, coverage = 0.1473, popularity = 5.5068, p_at_k = 0.0065, ndcg = 0.0079
# n = 10, k = 40, recall = 0.0968, precision = 0.2053, coverage = 0.1345, popularity = 5.5006, p_at_k = 0.0027, ndcg = 0.0027
# n = 10, k = 80, recall = 0.0967, precision = 0.2051, coverage = 0.1267, popularity = 5.5088, p_at_k = 0.0027, ndcg = 0.0027
# n = 10, k = 160, recall = 0.0982, precision = 0.2083, coverage = 0.1339, popularity = 5.5108, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 40, k = 5, recall = 0.2600, precision = 0.1429, coverage = 0.6394, popularity = 4.8455, p_at_k = 0.4191, ndcg = 0.5326
# n = 40, k = 20, recall = 0.2797, precision = 0.1483, coverage = 0.4091, popularity = 5.2129, p_at_k = 0.0585, ndcg = 0.1331
# n = 40, k = 40, recall = 0.2726, precision = 0.1445, coverage = 0.3158, popularity = 5.2802, p_at_k = 0.0116, ndcg = 0.0268
# n = 40, k = 80, recall = 0.2584, precision = 0.1370, coverage = 0.2715, popularity = 5.3031, p_at_k = 0.0053, ndcg = 0.0070
# n = 40, k = 160, recall = 0.2562, precision = 0.1358, coverage = 0.2442, popularity = 5.3044, p_at_k = 0.0017, ndcg = 0.0036
#
#
# inverse user frequence
# n = 1, k = 5, recall = 0.0135, precision = 0.2874, coverage = 0.0364, popularity = 5.7309, p_at_k = 0.0000, ndcg = 116.0000
# n = 1, k = 20, recall = 0.0136, precision = 0.2884, coverage = 0.0448, popularity = 5.7232, p_at_k = 0.0000, ndcg = 45.0000
# n = 1, k = 40, recall = 0.0141, precision = 0.2990, coverage = 0.0473, popularity = 5.7442, p_at_k = 0.0000, ndcg = 39.0000
# n = 1, k = 80, recall = 0.0141, precision = 0.2990, coverage = 0.0467, popularity = 5.7516, p_at_k = 0.0000, ndcg = 37.0000
# n = 1, k = 160, recall = 0.0147, precision = 0.3128, coverage = 0.0473, popularity = 5.7737, p_at_k = 0.0000, ndcg = 39.0000
#
# n = 3, k = 5, recall = 0.0370, precision = 0.2619, coverage = 0.0782, popularity = 5.6596, p_at_k = 0.5590, ndcg = 1.1784
# n = 3, k = 20, recall = 0.0366, precision = 0.2587, coverage = 0.0770, popularity = 5.6590, p_at_k = 0.1584, ndcg = 0.4179
# n = 3, k = 40, recall = 0.0367, precision = 0.2595, coverage = 0.0794, popularity = 5.6601, p_at_k = 0.1284, ndcg = 0.3357
# n = 3, k = 80, recall = 0.0374, precision = 0.2644, coverage = 0.0776, popularity = 5.6706, p_at_k = 0.1113, ndcg = 0.2658
# n = 3, k = 160, recall = 0.0383, precision = 0.2708, coverage = 0.0782, popularity = 5.6938, p_at_k = 0.1082, ndcg = 0.2422
#
# n = 5, k = 5, recall = 0.0578, precision = 0.2450, coverage = 0.1152, popularity = 5.5945, p_at_k = 0.7209, ndcg = 1.0970
# n = 5, k = 20, recall = 0.0578, precision = 0.2454, coverage = 0.0958, popularity = 5.6166, p_at_k = 0.2306, ndcg = 0.4561
# n = 5, k = 40, recall = 0.0568, precision = 0.2411, coverage = 0.0994, popularity = 5.6075, p_at_k = 0.1552, ndcg = 0.3240
# n = 5, k = 80, recall = 0.0568, precision = 0.2407, coverage = 0.0994, popularity = 5.6165, p_at_k = 0.1407, ndcg = 0.2508
# n = 5, k = 160, recall = 0.0587, precision = 0.2490, coverage = 0.1042, popularity = 5.6357, p_at_k = 0.1215, ndcg = 0.2152
#
# n = 10, k = 5, recall = 0.0997, precision = 0.2115, coverage = 0.2176, popularity = 5.4335, p_at_k = 0.8344, ndcg = 1.0028
# n = 10, k = 20, recall = 0.1026, precision = 0.2176, coverage = 0.1388, popularity = 5.5299, p_at_k = 0.3203, ndcg = 0.4957
# n = 10, k = 40, recall = 0.1011, precision = 0.2143, coverage = 0.1352, popularity = 5.5182, p_at_k = 0.2087, ndcg = 0.3161
# n = 10, k = 80, recall = 0.1003, precision = 0.2126, coverage = 0.1297, popularity = 5.5250, p_at_k = 0.1646, ndcg = 0.2511
# n = 10, k = 160, recall = 0.1009, precision = 0.2140, coverage = 0.1364, popularity = 5.5379, p_at_k = 0.1430, ndcg = 0.2108
#
# n = 40, k = 5, recall = 0.2645, precision = 0.1475, coverage = 0.6255, popularity = 4.9135, p_at_k = 0.9377, ndcg = 0.9847
# n = 40, k = 20, recall = 0.2844, precision = 0.1508, coverage = 0.3994, popularity = 5.2320, p_at_k = 0.6169, ndcg = 0.8145
# n = 40, k = 40, recall = 0.2824, precision = 0.1498, coverage = 0.3048, popularity = 5.2903, p_at_k = 0.3835, ndcg = 0.5454
# n = 40, k = 80, recall = 0.2721, precision = 0.1443, coverage = 0.2630, popularity = 5.3007, p_at_k = 0.2394, ndcg = 0.3445
# n = 40, k = 160, recall = 0.2675, precision = 0.1418, coverage = 0.2455, popularity = 5.3019, p_at_k = 0.1820, ndcg = 0.2456
#
#
# Normalized Similarity
# n = 1, k = 5, recall = 0.0140, precision = 0.2959, coverage = 0.0497, popularity = 5.6403, p_at_k = 0.0000, ndcg = 0.0000
# n = 1, k = 20, recall = 0.0138, precision = 0.2927, coverage = 0.0467, popularity = 5.6619, p_at_k = 0.0000, ndcg = 0.0000
# n = 1, k = 40, recall = 0.0131, precision = 0.2778, coverage = 0.0485, popularity = 5.6776, p_at_k = 0.0000, ndcg = 0.0000
# n = 1, k = 80, recall = 0.0137, precision = 0.2906, coverage = 0.0527, popularity = 5.6878, p_at_k = 0.0000, ndcg = 0.0000
# n = 1, k = 160, recall = 0.0139, precision = 0.2948, coverage = 0.0552, popularity = 5.7009, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 3, k = 5, recall = 0.0360, precision = 0.2542, coverage = 0.0945, popularity = 5.5600, p_at_k = 0.0000, ndcg = 0.0000
# n = 3, k = 20, recall = 0.0365, precision = 0.2577, coverage = 0.0836, popularity = 5.6082, p_at_k = 0.0000, ndcg = 0.0000
# n = 3, k = 40, recall = 0.0350, precision = 0.2474, coverage = 0.0836, popularity = 5.6057, p_at_k = 0.0000, ndcg = 0.0000
# n = 3, k = 80, recall = 0.0357, precision = 0.2524, coverage = 0.0836, popularity = 5.6105, p_at_k = 0.0000, ndcg = 0.0000
# n = 3, k = 160, recall = 0.0365, precision = 0.2584, coverage = 0.0861, popularity = 5.6228, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 5, k = 5, recall = 0.0561, precision = 0.2378, coverage = 0.1497, popularity = 5.4955, p_at_k = 0.0000, ndcg = 0.0000
# n = 5, k = 20, recall = 0.0565, precision = 0.2394, coverage = 0.1103, popularity = 5.5674, p_at_k = 0.0000, ndcg = 0.0000
# n = 5, k = 40, recall = 0.0549, precision = 0.2331, coverage = 0.1061, popularity = 5.5617, p_at_k = 0.0000, ndcg = 0.0000
# n = 5, k = 80, recall = 0.0558, precision = 0.2367, coverage = 0.1042, popularity = 5.5677, p_at_k = 0.0000, ndcg = 0.0000
# n = 5, k = 160, recall = 0.0568, precision = 0.2411, coverage = 0.1097, popularity = 5.5757, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 10, k = 5, recall = 0.0981, precision = 0.2081, coverage = 0.2624, popularity = 5.3341, p_at_k = 0.0100, ndcg = 0.0223
# n = 10, k = 20, recall = 0.1011, precision = 0.2143, coverage = 0.1612, popularity = 5.4847, p_at_k = 0.0000, ndcg = 0.0000
# n = 10, k = 40, recall = 0.0997, precision = 0.2113, coverage = 0.1455, popularity = 5.4823, p_at_k = 0.0000, ndcg = 0.0000
# n = 10, k = 80, recall = 0.0975, precision = 0.2069, coverage = 0.1388, popularity = 5.4911, p_at_k = 0.0000, ndcg = 0.0000
# n = 10, k = 160, recall = 0.0995, precision = 0.2111, coverage = 0.1412, popularity = 5.4936, p_at_k = 0.0000, ndcg = 0.0000
#
# n = 40, k = 5, recall = 0.2582, precision = 0.1420, coverage = 0.6673, popularity = 4.7920, p_at_k = 0.1454, ndcg = 0.2736
# n = 40, k = 20, recall = 0.2838, precision = 0.1505, coverage = 0.4400, popularity = 5.1781, p_at_k = 0.0053, ndcg = 0.0161
# n = 40, k = 40, recall = 0.2784, precision = 0.1476, coverage = 0.3509, popularity = 5.2562, p_at_k = 0.0014, ndcg = 0.0041
# n = 40, k = 80, recall = 0.2661, precision = 0.1411, coverage = 0.2800, popularity = 5.2854, p_at_k = 0.0006, ndcg = 0.0023
# n = 40, k = 160, recall = 0.2615, precision = 0.1387, coverage = 0.2582, popularity = 5.2870, p_at_k = 0.0000, ndcg = 0.0000

# %%
'''
@author: Lockvictor
'''
import sys, random, math
from operator import itemgetter


random.seed(0)


class ItemBasedCF():
    ''' TopN recommendation - ItemBasedCF '''
    def __init__(self):
        self.trainset = {}
        self.testset = {}

        self.n_sim_movie = 20
        self.n_rec_movie = 10

        self.movie_sim_mat = {}
        self.movie_popular = {}
        self.movie_count = 0

        print >> sys.stderr, 'Similar movie number = %d' % self.n_sim_movie
        print >> sys.stderr, 'Recommended movie number = %d' % self.n_rec_movie


    @staticmethod
    def loadfile(filename):
        ''' load a file, return a generator. '''
        fp = open(filename, 'r')
        for i, line in enumerate(fp):
            yield line.strip('\r\n')
            if i % 100000 == 0:
                print >> sys.stderr, 'loading %s(%s)' % (filename, i)
        fp.close()
        print >> sys.stderr, 'load %s succ' % filename


    def generate_dataset(self, filename, pivot=0.7):
        ''' load rating data and split it to training set and test set '''
        trainset_len = 0
        testset_len = 0

        for line in self.loadfile(filename):
            user, movie, rating, _ = line.split('::')
            # split the data by pivot
            if (random.random() < pivot):
                self.trainset.setdefault(user, {})
                self.trainset[user][movie] = int(round(float(rating)))
                trainset_len += 1
            else:
                self.testset.setdefault(user, {})
                self.testset[user][movie] = int(round(float(rating)))
                testset_len += 1

        print >> sys.stderr, 'split training set and test set succ'
        print >> sys.stderr, 'train set = %s' % trainset_len
        print >> sys.stderr, 'test set = %s' % testset_len


    def calc_movie_sim(self):
        ''' calculate movie similarity matrix '''
        print >> sys.stderr, 'counting movies number and popularity...'

        for user, movies in self.trainset.iteritems():
            for movie in movies:
                # count item popularity 
                if movie not in self.movie_popular:
                    self.movie_popular[movie] = 0
                self.movie_popular[movie] += 1

        print >> sys.stderr, 'count movies number and popularity succ'

        # save the total number of movies
        self.movie_count = len(self.movie_popular)
        print >> sys.stderr, 'total movie number = %d' % self.movie_count

        # count co-rated users between items
        itemsim_mat = self.movie_sim_mat
        print >> sys.stderr, 'building co-rated users matrix...'

        for user, movies in self.trainset.iteritems():
            for m1 in movies:
                for m2 in movies:
                    if m1 == m2: continue
                    itemsim_mat.setdefault(m1,{})
                    itemsim_mat[m1].setdefault(m2,0)
                    itemsim_mat[m1][m2] += 1

        print >> sys.stderr, 'build co-rated users matrix succ'

        # calculate similarity matrix 
        print >> sys.stderr, 'calculating movie similarity matrix...'
        simfactor_count = 0
        PRINT_STEP = 2000000

        for m1, related_movies in itemsim_mat.iteritems():
            for m2, count in related_movies.iteritems():
                itemsim_mat[m1][m2] = count / math.sqrt(
                        self.movie_popular[m1] * self.movie_popular[m2])
                simfactor_count += 1
                if simfactor_count % PRINT_STEP == 0:
                    print >> sys.stderr, 'calculating movie similarity factor(%d)' % simfactor_count

        print >> sys.stderr, 'calculate movie similarity matrix(similarity factor) succ'
        print >> sys.stderr, 'Total similarity factor number = %d' %simfactor_count


    def recommend(self, user):
        ''' Find K similar movies and recommend N movies. '''
        K = self.n_sim_movie
        N = self.n_rec_movie
        rank = {}
        watched_movies = self.trainset[user]

        for movie, rating in watched_movies.iteritems():
            for related_movie, w in sorted(self.movie_sim_mat[movie].items(),
                    key=itemgetter(1), reverse=True)[:K]:
                if related_movie in watched_movies:
                    continue
                rank.setdefault(related_movie, 0)
                rank[related_movie] += w * rating
        # return the N best movies
        return sorted(rank.items(), key=itemgetter(1), reverse=True)[:N]


    def evaluate(self):
        ''' return precision, recall, coverage and popularity '''
        print >> sys.stderr, 'Evaluation start...'

        N = self.n_rec_movie
        #  varables for precision and recall 
        hit = 0
        rec_count = 0
        test_count = 0
        # varables for coverage
        all_rec_movies = set()
        # varables for popularity
        popular_sum = 0

        for i, user in enumerate(self.trainset):
            if i % 500 == 0:
                print >> sys.stderr, 'recommended for %d users' % i
            test_movies = self.testset.get(user, {})
            rec_movies = self.recommend(user)
            for movie, w in rec_movies:
                if movie in test_movies:
                    hit += 1
                all_rec_movies.add(movie)
                popular_sum += math.log(1 + self.movie_popular[movie])
            rec_count += N
            test_count += len(test_movies)

        precision = hit / (1.0 * rec_count)
        recall = hit / (1.0 * test_count)
        coverage = len(all_rec_movies) / (1.0 * self.movie_count)
        popularity = popular_sum / (1.0 * rec_count)

        print >> sys.stderr, 'precision=%.4f\trecall=%.4f\tcoverage=%.4f\tpopularity=%.4f' \
                % (precision, recall, coverage, popularity)


if __name__ == '__main__':
    ratingfile = 'C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat'
    itemcf = ItemBasedCF()
    itemcf.generate_dataset(ratingfile)
    itemcf.calc_movie_sim()
    itemcf.evaluate()
# Out:
# Similar movie number = 20
# Recommended movie number = 10
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(0)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(100000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(200000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(300000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(400000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(500000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(600000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(700000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(800000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(900000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(1000000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(1100000)
# loading C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat(1200000)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a36bcc47e4aa> in <module>()
#     164     ratingfile = 'C:/Users/Fizik/Downloads/coursera/nir/nir/movielens/ratings.dat'
#     165     itemcf = ItemBasedCF()
# --> 166     itemcf.generate_dataset(ratingfile)
#     167     itemcf.calc_movie_sim()
#     168     itemcf.evaluate()
#
# <ipython-input-6-a36bcc47e4aa> in generate_dataset(self, filename, pivot)
#      43         testset_len = 0
#      44
# ---> 45         for line in self.loadfile(filename):
#      46             user, movie, rating, _ = line.split('::')
#      47             # split the data by pivot
#
# <ipython-input-6-a36bcc47e4aa> in loadfile(filename)
#      31         fp = open(filename, 'r')
#      32         for i, line in enumerate(fp):
# ---> 33             yield line.strip('\r\n')
#      34             if i % 100000 == 0:
#      35                 print >> sys.stderr, 'loading %s(%s)' % (filename, i)
#
# KeyboardInterrupt:
